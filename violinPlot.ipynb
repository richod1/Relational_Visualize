# %% [markdown]
# <a href="https://colab.research.google.com/github/richod1/Relational_Visualize/blob/main/violinPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data=sns.load_dataset("tips")
print(data.head())
plt.figure(figsize=(10,8))
sns.violinplot(x=data['total_bill'])
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(12,10))
sns.violinplot(x="day",y="total_bill",data=data)
plt.show()
